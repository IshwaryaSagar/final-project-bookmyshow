# %%
import movie
b = movie.movie_tickets()
while True:
    print('==================================================')
    print('1. Show the seats')
    print('2. Buy a tickets')
    print('3. Statistics')
    print('4. Show booked ticket user info')
    print('0. Exit')
    choice = input('Please select your choice from above: ')
    while choice.isdigit()==False:
        print('Please choose the choice in numbers')
        choice = input('Please select your choice from above: ')
        continue
    choice = int(choice)
    if choice==0:
        print(" THANK YOU & VISIT AGAIN ".center(80,'-'))
        break
    if choice ==1:
        b.show_seats()
    elif choice == 2:
        b.buy_ticket()
    elif choice==3:
        b.statistics()
    elif choice == 4:
        b.get_details()
# Out:
# -------------------------- WELCOME TO RAJITHA'S MOVIE --------------------------
# Enter No.of Rows :9
# Enter No.of Columns :9
# ==================================================
# 1. Show the seats
# 2. Buy a tickets
# 3. Statistics
# 4. Show booked ticket user info
# 0. Exit
# Please select your choice from above: 1
# ---------------------------- SCREEN IS ON THIS SIDE ----------------------------
# Seats :
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# ==================================================
# 1. Show the seats
# 2. Buy a tickets
# 3. Statistics
# 4. Show booked ticket user info
# 0. Exit
# Please select your choice from above: 2
# ------------------------------- BOOKING COUNTER --------------------------------
# Please select the seats between 9 rows and 9 columns
# Please select the row : 5
# Please select the column : 5
# Please select the name in alphabets!
# Please enter your name: jashvitha
# Please enter your age: 5
# Please select your gender Female/Male/Other: female
# Please enter your phone number1234567890
# Confirm to book seats(Yes/No): yes
# Your ticket price is 8$, if you want to confirm, Please type Yes/No: yes
# ---------------------------- SCREEN IS ON THIS SIDE ----------------------------
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * B * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# * * * * * * * * *
# ==================================================
# 1. Show the seats
# 2. Buy a tickets
# 3. Statistics
# 4. Show booked ticket user info
# 0. Exit
# Please select your choice from above: 3
# ----------------------- TOTAL INCOME FOR RAJITHA'S MOVIE -----------------------
# Total number of seats booked are :  1
# Booking percentage is :  1.2345679012345678
# current income is : 8 $
# Total income is: 728 $
# ==================================================
# 1. Show the seats
# 2. Buy a tickets
# 3. Statistics
# 4. Show booked ticket user info
# 0. Exit
# Please select your choice from above: 4
# ------------------------------- CUSTOMER DETAILS -------------------------------
# Please enter row number you want: 5
# Please enter column number you want: 5
# name: Jashvitha
# age: 5
# Gender: Female
# Phone Number: 1234567890
# Ticket Price: 8$
# ==================================================
# 1. Show the seats
# 2. Buy a tickets
# 3. Statistics
# 4. Show booked ticket user info
# 0. Exit
# Please select your choice from above: 0
# --------------------------- THANK YOU & VISIT AGAIN ----------------------------
